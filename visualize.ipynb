# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
# Load a sample dataset (adjust path and loader as needed)
public_data = np.load("dataset/public.npy")  

# Shape: [num_samples, num_features]
public_data.shape
# Out:
# (65000, 1280)

# %%
public_data[0]
# Out:
# array([ 0.15759309,  0.19661824,  1.26968217, ..., -0.04564809,
#        -0.10780814,  0.19444717])

# %%
private_data = np.load("dataset/private.npy")  

private_data.shape
# Out:
# (65000, 1280)

# %%
public_data[0]
# Out:
# array([ 0.15759309,  0.19661824,  1.26968217, ..., -0.04564809,
#        -0.10780814,  0.19444717])

# %%
train_data = np.load("dataset/train.npy")  

train_data.shape
# Out:
# (210000, 1280)

# %%
train_data[0]
# Out:
# array([-0.07917264,  0.46916676,  0.14226654, ...,  0.11830179,
#        -0.0944516 ,  0.2165211 ])

# %%
# Plot histograms for the first 5 features
plt.figure(figsize=(12, 8))
for i in range(5):  # Adjust the range if you want more or fewer features
    plt.hist(train_data[:, i], bins=50, alpha=0.6, label=f"Feature {i+1}")
plt.xlabel("Feature Value")
plt.ylabel("Frequency")
plt.title("Distribution of First 5 Features")
plt.legend()
plt.show()

# %%
# Select a smaller subset, say the first 100 samples
subset_data = train_data[:100]

plt.figure(figsize=(15, 10))
sns.heatmap(subset_data.T, cmap="viridis", cbar=True)
plt.xlabel("Sample Index (First 100)")
plt.ylabel("Feature Index")
plt.title("Heatmap of Features for First 100 Samples")
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# Reduce dimensions to 2D using PCA
pca = PCA(n_components=2)
train_data_pca = pca.fit_transform(train_data[:5000])  # Use a subset (e.g., first 5000 samples) for visualization

plt.figure(figsize=(10, 8))
plt.scatter(train_data_pca[:, 0], train_data_pca[:, 1], s=1, alpha=0.5, cmap='viridis')
plt.colorbar(label="Sample Index")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.title("2D PCA of Training Data")
plt.show()
# Out:
# /var/folders/dc/p853qg_90djd6z05f_v8jrd00000gn/T/ipykernel_33318/1650152161.py:9: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(train_data_pca[:, 0], train_data_pca[:, 1], s=1, alpha=0.5, cmap='viridis')
